# %%
# !unzip amazon-fine-food-reviews.zip
# Out:
# Archive:  amazon-fine-food-reviews.zip
#   inflating: Reviews.csv
#   inflating: database.sqlite
#   inflating: hashes.txt

# %% [markdown]
# ## Business Case

# %% [markdown]
# The web contains enormous amounts of user generated data. One huge source of such information can be found in the myriads of customer written complaints and reviews.
#
# The aim of this data challenge is to show that it is possible to extract useful insights from text and that there is value in text data. Can you convince the C-suite of an online food seller company that there is value in working with the text data? In a first meeting you want to show them, that a machine learning model can learn from the review summary and the review itself to distinguish between different levels of consumer satisfaction.
#
#
#
# The situation in a little more detail
#
# The food retailer wants to understand their users as well as users feelings about the products they are selling.
#
# How could a model as described above help in this situation? Make assumptions or educated guesses if some details are missing that you would like to use for your argument.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_reviews = pd.read_csv('Reviews.csv')

# %% [markdown]
# ## Data Description

# %% [markdown]
# This dataset consists of reviews of fine foods from amazon. The data span a period of more than 10 years, including all ~500,000 reviews up to October 2012. Reviews include product and user information, ratings, and a plain text review. It also includes reviews from all other Amazon categories.
#
# Data includes:
#
# - Reviews from Oct 1999 - Oct 2012
# - 568,454 reviews
# - 256,059 users
# - 74,258 products
# - 260 users with > 50 reviews
#
# Columns:
#
# - Id Row Id
# - ProductId Unique identifier for the product
# - UserId Unqiue identifier for the user
# - ProfileName Profile name of the user
# - HelpfulnessNumerator Number of users who found the review helpful
# - HelpfulnessDenominator Number of users who indicated whether they found the review helpful or not
# - Score Rating between 1 and 5
# - Time Timestamp for the review
# - Summary Brief summary of the review
# - Text Text of the review

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568438 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %% [markdown]
# => **'ProfileName' and 'Summary' contains nulls**

# %%
df_reviews.describe(include='all')
# Out:
#                    Id   ProductId          UserId       ProfileName  \
# count   568454.000000      568454          568454            568438
# unique            NaN       74258          256059            218416
# top               NaN  B007JFMH8M  A3OXHLG6DIBRW8  C. F. Hill "CFH"
# freq              NaN         913             448               451
# mean    284227.500000         NaN             NaN               NaN
# std     164098.679298         NaN             NaN               NaN
# min          1.000000         NaN             NaN               NaN
# 25%     142114.250000         NaN             NaN               NaN
# 50%     284227.500000         NaN             NaN               NaN
# 75%     426340.750000         NaN             NaN               NaN
# max     568454.000000         NaN             NaN               NaN
#
#         HelpfulnessNumerator  HelpfulnessDenominator          Score  \
# count          568454.000000            568454.00000  568454.000000
# unique                   NaN                     NaN            NaN
# top                      NaN                     NaN            NaN
# freq                     NaN                     NaN            NaN
# mean                1.743817                 2.22881       4.183199
# std                 7.636513                 8.28974       1.310436
# min                 0.000000                 0.00000       1.000000
# 25%                 0.000000                 0.00000       4.000000
# 50%                 0.000000                 1.00000       5.000000
# 75%                 2.000000                 2.00000       5.000000
# max               866.000000               923.00000       5.000000
#
#                 Time     Summary  \
# count   5.684540e+05      568427
# unique           NaN      295742
# top              NaN  Delicious!
# freq             NaN        2462
# mean    1.296257e+09         NaN
# std     4.804331e+07         NaN
# min     9.393408e+08         NaN
# 25%     1.271290e+09         NaN
# 50%     1.311120e+09         NaN
# 75%     1.332720e+09         NaN
# max     1.351210e+09         NaN
#
#                                                      Text
# count                                              568454
# unique                                             393579
# top     This review will make me sound really stupid, ...
# freq                                                  199
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
df_reviews.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ### Score

# %%
df_reviews['Score'].unique()
# Out:
# array([5, 1, 4, 2, 3], dtype=int64)

# %%
pd.crosstab(df_reviews['Score'],'count')
# Out:
# col_0   count
# Score
# 1       52268
# 2       29769
# 3       42640
# 4       80655
# 5      363122

# %% [markdown]
# categorical variable 'score' looks like the perfect candidate for the target variable for the sentiment analysis. It has 5 different categories ranging from 1 to 5. Let's consider the categories 0 and 1 as negative reviews, the category 2 as neutral and the categories 4 and 5 as positive reviews. But the categories are **not balanced** (category 5 has a lot more entries than category 2).

# %% [markdown]
# ### ProductId

# %%
len(df_reviews['ProductId'].unique())
# Out:
# 74258

# %% [markdown]
# There are more than one review about the same product but which product was reviewed most often?

# %%
df_reviews['ProductId'].value_counts()[:10]
# Out:
# B007JFMH8M    913
# B002QWP89S    632
# B002QWHJOU    632
# B0026RQTGE    632
# B002QWP8H0    632
# B003B3OOPA    623
# B001EO5Q64    567
# B0013NUGDE    564
# B007M832YY    564
# B007M83302    564
# Name: ProductId, dtype: int64

# %% [markdown]
# How many products were reviewed only once?

# %%
df_reviews['ProductId'].value_counts()[df_reviews['ProductId'].value_counts() == 1].count()
# Out:
# 30408

# %%
df_reviews['ProductId'].value_counts().value_counts()
# Out:
# 1      30408
# 2      12262
# 3       6849
# 4       4324
# 5       3105
#        ...
# 280        1
# 216        1
# 343        1
# 330        1
# 191        1
# Name: ProductId, Length: 283, dtype: int64

# %% [markdown]
# Many products have only a small number of reviews

# %% [markdown]
# ### UserId

# %%
df_reviews['UserId'].value_counts()
# Out:
# A3OXHLG6DIBRW8    448
# A1YUL9PCJR3JTY    421
# AY12DBB0U420B     389
# A281NPSIMI1C2R    365
# A1Z54EM24Y40LL    256
#                  ...
# ASOOYVBM0UTF1       1
# A27F7HLEP036YC      1
# ATTZKFYQDA7FF       1
# A5WAU830DFLJO       1
# A2VPYAUZ0NV9CK      1
# Name: UserId, Length: 256059, dtype: int64

# %% [markdown]
# Some users reviewed more than once, especially user 'A3OXHLG6DIBRW8' reviewed 448 times. Which products did this user review?

# %%
df_reviews[df_reviews['UserId'] == df_reviews['UserId'].value_counts().index[0]]['ProductId'].value_counts()
# Out:
# B000AY9UBQ    2
# B000GPXRS6    2
# B004175FQC    2
# B000AYFCEU    2
# B0076MLL12    2
#              ..
# B0000SXENM    1
# B000LQJT1O    1
# B001FA1DYG    1
# B007JBO41E    1
# B0032IGJ8E    1
# Name: ProductId, Length: 420, dtype: int64

# %% [markdown]
# This user reviewed some products more than once!
#
# How many users reviewed the same product more than once?

# %%
g = df_reviews.groupby(['UserId','ProductId']).size().reset_index(name='Size')
len(g[g['Size'] > 1]['UserId'].unique())
# Out:
# 1243

# %% [markdown]
# 1243 user reviewed a product more than once

# %% [markdown]
# ### ProfileName

# %% [markdown]
# If we compare the statistics from above 'ProfileName' and 'UserId' are not always the same, i.e. the same user can have several profile names.
#
# Or can one profile name have more than one user id?

# %%
g = df_reviews.groupby(['UserId'])['ProfileName'].agg(['nunique','unique']).reset_index()
g[g['nunique'] > 1]
# Out:
#                 UserId  nunique  \
# 3077    A11CK6P4SLO6RU        2
# 7091    A13K3ZLWAWN1EI        2
# 13450   A16YH487W9ZYO0        2
# 19150   A1A0MBT5LKK8U9        2
# 24222   A1CRT2UI0YIOQN        2
# 24419   A1CVN6FWUCZOMD        2
# 25048   A1D76XJYSQPKIU        2
# 35137   A1ILMC39P2KWI2        2
# 40134    A1L8O1760QA1M        2
# 41128   A1LS1WB7HSPMF1        2
# 46426   A1OLSDX3B8CN10        2
# 51682    A1RET8URKV6NV        2
# 53437   A1SDKIU8VPW1K8        2
# 57295   A1UGH9YA5PFRGA        2
# 64337   A1Y78YZQQMKFBY        2
# 73168   A22V22KRTSNU19        2
# 74748   A23Q74Y9YOFK8W        2
# 76255   A24IMIHTTLIRX0        2
# 84485   A28WBCAWHZXTR9        2
# 84547   A28XNOJO8LRQ4F        2
# 92203   A2CZ4OA313WSKS        2
# 95030   A2EGK0YRDF4ZZB        2
# 95351   A2EMM13TIU7IML        2
# 99504   A2GUJ4ZEQIEW4G        2
# 100065  A2H667ZUNLNTF1        2
# 103377  A2IW5P1NA5EK60        2
# 104899  A2JPUJ5ISXQ90F        2
# 108234  A2LGWBIT9WCTVA        2
# 112678  A2NUBL2UYWPBWR        2
# 113554  A2OAYIM13WIXCH        2
# 121371  A2SGOIASETW3UB        2
# 121944  A2SRVDDDOQ8QJL        2
# 129022  A2WJH1QD0M9X51        2
# 131908  A2Y1C320S3S1HY        2
# 148249   A36T832OV91TN        2
# 150561  A3827I7HIP1LMB        2
# 168681  A3HQKGTU3EQXXZ        2
# 175784  A3LL0U6E3QK34A        2
# 178860  A3N9DN0V2YXAXA        2
# 186722  A3RFWQMLYSAKI0        2
# 187182  A3ROT6HPAGL4CA        2
# 193061  A3UUJ6UADL8666        2
# 193132  A3UVT34TSPF5W4        2
# 225266   AJQD2WWJYOYFQ        2
# 228816   ALLLTEZ0I5US0        2
# 233554   AO2Z6SCI5TDBJ        2
# 235307   AP0K8XE7AIIVZ        2
# 239448   AR9IGTVTL5Y4O        2
# 250392   AX148M3X6EUGN        2
# 252536   AY52TNOUURNB8        2
#
#                                                    unique
# 3077                             [K. Dresser, A Customer]
# 7091                       [yogagirl "grrrl", A Customer]
# 13450                      [Bruce G. Lindsay, A Customer]
# 19150                                 [Lance, A Customer]
# 24222                                [Krista, A Customer]
# 24419                         [his_billyness, A Customer]
# 25048                             [A. Bowens, A Customer]
# 35137                           [A Customer, D. Schwartz]
# 40134                                 [Mauby, A Customer]
# 41128                                [A Customer, Porter]
# 46426      [Cara K. Smith "Georgia Garderer", A Customer]
# 51682                                [Melvin, A Customer]
# 53437                            [A Customer, D. Barnard]
# 57295         [Jennifer Fahlsing "jfahlsing", A Customer]
# 64337                              [S. Leyva, A Customer]
# 73168                 [M. Bontekoe "cowgirl", A Customer]
# 74748                      [A Customer, Jo-anne Peterson]
# 76255   [Karen Syed "Karen L Syed, Reader/Author/Publi...
# 84485                       [Barbara Hillier, A Customer]
# 84547                               [quilter, A Customer]
# 92203                   [albert camus "alby", A Customer]
# 95030                   [AV8R "Cookbook Maven", S. Hodge]
# 95351                             [I. Santos, A Customer]
# 99504              [S. Christiansen "foodie", A Customer]
# 100065  [Wendi Barker "Wendi's Book Corner & What Wend...
# 103377                     [Happy Daughter, C. Dougherty]
# 104899                       [Riki M. "Riki", A Customer]
# 108234                          [D. Gesswein, A Customer]
# 112678                                           [C, TCL]
# 113554     [Mary D. Haper "Gramma to 3 boys", A Customer]
# 121371                         [A Customer, April Steele]
# 121944                               [MJ23447, M. J Lane]
# 129022                     [Heather Ferguson, Heather F.]
# 131908      [A Customer, Discriminating "Discriminating"]
# 148249                                  [AMS, A.M. Schor]
# 150561                            [christine, A Customer]
# 168681                            [hellokaty, A Customer]
# 175784                            [A Customer, K. Biddle]
# 178860                        [musicalcharge, A Customer]
# 186722       [A Customer, Michael Burkett "reader rider"]
# 187182                 [Howster, Howard Howell "Howster"]
# 193061                       [A. D. Mucciolo, A Customer]
# 193132                            [B. Schorr, A Customer]
# 225266                              [bubbles, A Customer]
# 228816                           [L. Spencer, A Customer]
# 233554                        [S. E. Fanning, A Customer]
# 235307                                  [ABP, A Customer]
# 239448                [Mary A. LaRock "Gran", A Customer]
# 250392  [Jennifer Dean "Paranormal Reader", Jennifer D...
# 252536                          [Yanping Liu, A Customer]

# %%
g[g['nunique'] > 1].shape
# Out:
# (50, 3)

# %%
df_reviews[df_reviews['UserId'] == 'AX148M3X6EUGN']
# Out:
#             Id   ProductId         UserId                        ProfileName  \
# 210833  210834  B001HBBQKY  AX148M3X6EUGN  Jennifer Dean "Paranormal Reader"
# 553565  553566  B0018CK0EU  AX148M3X6EUGN           Jennifer Dean "Jennifer"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 210833                     1                       2      1  1339113600
# 553565                     1                       2      5  1336694400
#
#                                      Summary  \
# 210833                       CHIHUAHUA PUPPY
# 553565  The Only Thing My Chihuahua Will Eat
#
#                                                      Text
# 210833  My five month old Chihuahua puppy wont eat the...
# 553565  This was a pricey gamble because my 4lb chihua...

# %%
df_reviews[df_reviews['ProfileName'].isna()].shape
# Out:
# (16, 10)

# %%
profile_names_nulls = df_reviews[df_reviews['ProfileName'].isna()]['UserId'].to_list()

# %%
df_reviews[df_reviews['UserId'].isin(profile_names_nulls)]
# Out:
#             Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 25509    25510  B000LKZB4Y  A36BVYD0NT7Z0F        None                     0
# 38874    38875  B000AYDGZ2  A36BVYD0NT7Z0F        None                     2
# 49800    49801  B000CRHQN0  A2LYFY32LXQDON        None                     0
# 67077    67078  B0006348H2  A2P0P67Y55SNOX        None                     1
# 106550  106551  B001EQ5DG0  A1P500QXEG3IUZ        None                     0
# 137613  137614  B000CQE3HS   AGT3BYX5P9SLH        None                     0
# 163191  163192  B000CQID1A   AGT3BYX5P9SLH        None                     0
# 172462  172463  B001FA1L9I   AC9U70TRGPDGJ        None                     0
# 297275  297276  B007OXJM6E  A29D7XVSBCLFLD        None                     0
# 306751  306752  B000RI1W8E   AGT3BYX5P9SLH        None                     0
# 431598  431599  B000W5P0KI  A36BVYD0NT7Z0F        None                    13
# 440825  440826  B008LFAS08   AC0E8TXIYABB5        None                     1
# 490412  490413  B000CQE3IC   AGT3BYX5P9SLH        None                     0
# 491728  491729  B004772PJQ  A29D7XVSBCLFLD        None                     0
# 515436  515437  B004S04X4W  A2H7605OSHVIQ5        None                     0
# 560446  560447  B000CQID1K   AGT3BYX5P9SLH        None                     0
#
#         HelpfulnessDenominator  Score        Time  \
# 25509                        0      5  1314576000
# 38874                        3      1  1278374400
# 49800                        0      2  1282608000
# 67077                        1      5  1314662400
# 106550                       0      5  1326758400
# 137613                       0      5  1324684800
# 163191                       0      5  1324684800
# 172462                       0      5  1289520000
# 297275                       0      1  1325203200
# 306751                       0      5  1324684800
# 431598                      21      1  1298937600
# 440825                       1      5  1350432000
# 490412                       0      5  1324684800
# 491728                       0      1  1325203200
# 515436                       0      5  1348704000
# 560446                       0      5  1324684800
#
#                                                   Summary  \
# 25509    These are the best mints and no aspartame or BHT
# 38874   doesn't anyone care that they are putting BHT ...
# 49800   They were melted and the chocolate had turned ...
# 67077                                          Wheatgrass
# 106550                                           Finally!
# 137613                                            awesome
# 163191                                            awesome
# 172462                                          very good
# 297275                                              Burnt
# 306751                                            awesome
# 431598               WARNING:  Please read before feeding
# 440825          The perfect grinder for dog and cat food!
# 490412                                            awesome
# 491728                                              Burnt
# 515436                   Hormel Roast Beef Hash, 15-Ounce
# 560446                                            awesome
#
#                                                      Text
# 25509   I was so shocked to find out that almost all g...
# 38874   I called Kellogg's to see why Special K red be...
# 49800   We love these bars but i won't order them ship...
# 67077   Kitty seems to like this sprinkled on her food...
# 106550  You cannot find this in the stores anymore, it...
# 137613  i love them they are amazing I would eat them ...
# 163191  i love them they are amazing I would eat them ...
# 172462  came in proper packaging.  Have loved British ...
# 297275  The last SEVERAL time we bought this it tasted...
# 306751  i love them they are amazing I would eat them ...
# 431598  WARNING:  I use to feed my dogs Orijen 75% pro...
# 440825  this grinder is super easy to assemble and ope...
# 490412  i love them they are amazing I would eat them ...
# 491728  The last SEVERAL time we bought this it tasted...
# 515436  I've been buying this in the grocery stores fr...
# 560446  i love them they are amazing I would eat them ...

# %%
df_reviews[df_reviews['UserId'].isin(profile_names_nulls)].shape
# Out:
# (16, 10)

# %% [markdown]
# The profile names with nulls have no other user id's with no nulls in the profile names

# %%
g = df_reviews.groupby(['ProfileName'])['UserId'].agg(['nunique','unique']).reset_index()
g[g['nunique'] > 1]
# Out:
#        ProfileName  nunique                                             unique
# 0                       2                     [ABCOLENOSM0IQ, AVJD277LH9Y4O]
# 33       "unknown"        2                   [A1B8RBFA887XP1, A290ECYG2HBEPB]
# 57           $Bill        2                   [A17YUAVQNZF0JL, A26SMQQFVASO2O]
# 127              *        3   [A3BU1N1GIYOENC, A2ZHRGS5ES8ONP, A15YMPC9C9WM6P]
# 132          *****        2                     [A6U2TRWX4LE9H, A1CZ5KBWV6XVM]
# ...            ...      ...                                                ...
# 218264       ziggy        2                    [A2CTA59ANQTQUQ, AUXNN5ECQPIVS]
# 218274        zimm        2                   [A3EZON367IP4UG, A11JIQ56GQ2Q4J]
# 218283         zip        2                    [AYLCZ8OQCEZCS, A32ZDO5O41K4SH]
# 218314         zoe        5  [AQXEWFFOX42O7, AXGZ2VX4XS4KW, A8ULSRCML9G6R, ...
# 218318        zoey        3   [A3L81X5FCP9KLG, A3LF6P89G3V9PY, A1ST5NYM5PBRVR]
#
# [10107 rows x 3 columns]

# %%
g['nunique'].max()
# Out:
# 166

# %% [markdown]
# We have 50 UserId's with more than one ProfileName but 10107 ProfileName's with more than one UserId. For instance 166 user id's have the same profile name.

# %% [markdown]
# ### HelpfullnessNumerator

# %%
df_reviews.boxplot(column='HelpfulnessNumerator')
